# %% [markdown]
# # 云端一键脚本 By bilibili@十字鱼
# - 十字鱼 https://space.bilibili.com/893892

# %% [markdown]
# ## 2.快速启动

# %% [markdown]
# ### 2.1 lam

# %%
import os
os.environ["PATH"]="/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/local/miniconda3/envs/glut/bin"
os.environ["MODELSCOPE_CACHE"]="/workspace/OpenAvatarChat"
os.environ["TORCH_HOME"]="/workspace/OpenAvatarChat/models"
os.environ["HF_ENDPOINT"]="https://hf-mirror.com"
# !df -hl #查看磁盘
# %cd /workspace/OpenAvatarChat
# !sh /workspace/OpenAvatarChat/scripts/setup_coturn.sh > /dev/null 2>&1
# !HF_ENDPOINT=https://hf-mirror.com python src/demo.py --config /workspace/glut.yaml
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         178G   16M  170G   1% /
# /dev/vda1        20G  4.4G   15G  23% /entrypoint.sh
# tmpfs            20G     0   20G   0% /dev/shm
# /dev/vda10      5.4M   24K  4.7M   1% /cloud
# /dev/vda2       178G   16M  170G   1% /etc/hosts
# tmpfs            20G   12K   20G   1% /proc/driver/nvidia
# tmpfs            20G     0   20G   0% /proc/acpi
# tmpfs            20G     0   20G   0% /sys/firmware
# tmpfs            20G     0   20G   0% /sys/devices/virtual/powercap
# tmpfs            20G     0   20G   0% /proc/scsi
# /workspace/OpenAvatarChat
# 2025-07-18 12:16:53.001 | INFO     | service.service_utils.service_config_loader:load_configs:23 - Load config with env default from /workspace/glut.yaml
# 2025-07-18 12:16:53.160 | INFO     | service.service_utils.logger_utils:config_loggers:8 - Set log level to INFO
# ...

# %% [markdown]
# ### 2.2 liteavatar

# %%
import os
os.environ["PATH"]="/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/local/miniconda3/envs/glut/bin"
os.environ["MODELSCOPE_CACHE"]="/workspace/OpenAvatarChat"
os.environ["TORCH_HOME"]="/workspace/OpenAvatarChat/models"
os.environ["HF_ENDPOINT"]="https://hf-mirror.com"
# !df -hl #查看磁盘
# %cd /workspace/OpenAvatarChat
# !sh /workspace/OpenAvatarChat/scripts/setup_coturn.sh > /dev/null 2>&1
# !HF_ENDPOINT=https://hf-mirror.com python src/demo.py --config /workspace/glut2.yaml

# %% [markdown]
# ### 2.3 musetalk

# %%
import os
os.environ["PATH"]="/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/local/miniconda3/envs/glut/bin"
os.environ["MODELSCOPE_CACHE"]="/workspace/OpenAvatarChat"
os.environ["TORCH_HOME"]="/workspace/OpenAvatarChat/models"
os.environ["HF_ENDPOINT"]="https://hf-mirror.com"
# !df -hl #查看磁盘
# %cd /workspace/OpenAvatarChat
# !sh /workspace/OpenAvatarChat/scripts/setup_coturn.sh > /dev/null 2>&1
# !HF_ENDPOINT=https://hf-mirror.com python src/demo.py --config /workspace/glut3.yaml
